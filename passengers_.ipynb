# %%
import pandas as pd
import numpy as np

# %%
flights = pd.read_csv('flights_2019_weather_full.csv')

# %%
passengers = pd.read_csv('average passengers.csv')

# %%
flights['month'] = pd.DatetimeIndex(flights['fl_date']).month
flights['year'] = pd.DatetimeIndex(flights['fl_date']).year

# %%
passengers.head()
# Out:
#    month dest origin  average_seats  average_passengers
# 0      1  1CA    HHR            9.0                 8.0
# 1      1  1G4    1G4          721.5               578.0
# 2      1  1G4    BLD          276.0                 0.0
# 3      1  1NC    RIC            8.0                 3.0
# 4      1  2CA    HHR            9.0                 2.0

# %%
flights.head()
# Out:
#       fl_date mkt_unique_carrier branded_code_share mkt_carrier  \
# 0  2019-01-01                 AA       AA_CODESHARE          AA
# 1  2019-01-01                 AA       AA_CODESHARE          AA
# 2  2019-01-01                 AA       AA_CODESHARE          AA
# 3  2019-01-01                 AA       AA_CODESHARE          AA
# 4  2019-01-01                 AA       AA_CODESHARE          AA
#
#    mkt_carrier_fl_num op_unique_carrier tail_num  op_carrier_fl_num  \
# 0                3044                OO   N761ND               3044
# 1                5606                OH   N575NN               5606
# 2                5607                OH   N254PS               5607
# 3                5607                OH   N254PS               5607
# 4                5608                OH   N710PS               5608
#
#    origin_airport_id origin  ... late_aircraft_delay  first_dep_time  \
# 0              13930    ORD  ...                 0.0             NaN
# ...

# %%
flights_pass = flights.merge(passengers,how='left',on=['month','origin','dest'] )

# %%
flights_pass['avg_passenger_capacity_usage'] = flights_pass['average_passengers']/flights_pass['average_seats']

# %%
flights_pass
# Out:
#            fl_date mkt_unique_carrier branded_code_share mkt_carrier  \
# 0       2019-01-01                 AA       AA_CODESHARE          AA
# 1       2019-01-01                 AA       AA_CODESHARE          AA
# 2       2019-01-01                 AA       AA_CODESHARE          AA
# 3       2019-01-01                 AA       AA_CODESHARE          AA
# 4       2019-01-01                 AA       AA_CODESHARE          AA
# ...            ...                ...                ...         ...
# 119995  2019-12-01                 WN                 WN          WN
# 119996  2019-12-01                 WN                 WN          WN
# 119997  2019-12-01                 WN                 WN          WN
# 119998  2019-12-01                 WN                 WN          WN
# 119999  2019-12-01                 WN                 WN          WN
#
#         mkt_carrier_fl_num op_unique_carrier tail_num  op_carrier_fl_num  \
# ...

# %%
flights_pass.to_csv('flights_2019_passengers.csv')
