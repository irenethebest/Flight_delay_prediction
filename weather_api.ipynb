# %%
import requests as re
import os
import pandas as pd
import numpy as np
from datetime import timedelta, date

# %%
flights = pd.read_csv('flights_2019.csv')

# %%
weather_api = os.environ['weather_api_key']

# %%
flights.tail()
# Out:
#            fl_date mkt_unique_carrier branded_code_share mkt_carrier  \
# 119995  2019-12-01                 WN                 WN          WN
# 119996  2019-12-01                 WN                 WN          WN
# 119997  2019-12-01                 WN                 WN          WN
# 119998  2019-12-01                 WN                 WN          WN
# 119999  2019-12-01                 WN                 WN          WN
#
#         mkt_carrier_fl_num op_unique_carrier tail_num  op_carrier_fl_num  \
# 119995                4721                WN   N961WN               4721
# 119996                5447                WN   N723SW               5447
# 119997                5021                WN   N739GB               5021
# 119998                5841                WN   N8549Z               5841
# 119999                2044                WN   N7839A               2044
#
#         origin_airport_id origin  ... late_aircraft_delay  first_dep_time  \
# ...

# %%
flights['fl_date'].nunique()
# Out:
# 31

# %%
dates_list = flights['fl_date'].unique().tolist()

# %%
dates_list2 = dates_list[20:]

# %%
airport_list = flights['origin'].unique().tolist()

# %%
len(airport_list)
# Out:
# 369

# %%
arr_list= flights['arr_date'].unique().tolist()

# %%
arr_list = arr_list[11:]

# %%
dest_list = flights['dest'].unique().tolist()

# %%
len(arr_dates)
# Out:
# 39

# %%
'''condition_list = []
for date in dates_list2:
    for airport in airport_list:
        url = 'http://api.weatherapi.com/v1/history.json?key='+weather_api+'&q='+airport+'&dt='+date+'&hour='+'12'
        r = re.get(url)
        res = r.json()
        temp_list = [date,airport,res['forecast']['forecastday'][0]['hour'][0]['condition']['text']]
        condition_list.append(temp_list)'''

# %%
'''arr_dates = pd.to_datetime(flights['fl_date'])
for date in range(len(arr_date)):
    if flights['crs_dep_time'][date] > flights['crs_arr_time'][date]:
        arr_date[date] = arr_date[date] + timedelta(days=1)
flights['arr_date'] = arr_date
flights['arr_date'] = flights['arr_date'].astype(str)'''

# %%
arr_condition_list = []
for date in arr_list:
    for airport in dest_list:
        url = 'http://api.weatherapi.com/v1/history.json?key='+weather_api+'&q='+airport+'&dt='+date+'&hour='+'12'
        r = re.get(url)
        res = r.json()
        temp_list = [date,airport,res['forecast']['forecastday'][0]['hour'][0]['condition']['text']]
        arr_condition_list.append(temp_list)

# %%
len(arr_condition_list)
# Out:
# 10332

# %%
arr_condition_list1 = arr_condition_list[:4058]

# %%
arr_condition_df = pd.DataFrame(data=arr_condition_list3,columns=['arr_date','dest', 'arr_condition'])

# %%
arr_condition_list2 = arr_condition_list

# %%
arr_condition_list3 = arr_condition_list1+arr_condition_list2

# %%
len(arr_condition_list3)
# Out:
# 14390

# %%
len(condition_list2)
# Out:
# 4059

# %%
len(condition_list1)
# Out:
# 7380

# %%
fcondition_list = condition_list1+condition_list2

# %%
len(fcondition_list)
# Out:
# 11439

# %%
condition_df = pd.DataFrame(data=fcondition_list,columns=['fl_date','origin', 'dep_condition'])

# %%
condition_df
# Out:
#           fl_date origin  dep_condition
# 0      2019-01-01    ORD       Overcast
# 1      2019-01-01    MYR         Cloudy
# 2      2019-01-01    BDL          Sunny
# 3      2019-01-01    DCA          Sunny
# 4      2019-01-01    ORF  Partly cloudy
# ...           ...    ...            ...
# 11434  2019-12-03    PPG          Sunny
# 11435  2019-12-03    ACK       Blizzard
# 11436  2019-12-03    MVY       Blizzard
# 11437  2019-12-03    HYA       Blizzard
# 11438  2019-12-03    XWA          Sunny
#
# [11439 rows x 3 columns]

# %%
flights_weather2 = flights_weather.merge(arr_condition_df,how='left',on=['arr_date','dest'] )

# %%
flights_weather['arr_date']=flights['arr_date']

# %%
flights_weather
# Out:
#            fl_date mkt_unique_carrier branded_code_share mkt_carrier  \
# 0       2019-01-01                 AA       AA_CODESHARE          AA
# 1       2019-01-01                 AA       AA_CODESHARE          AA
# 2       2019-01-01                 AA       AA_CODESHARE          AA
# 3       2019-01-01                 AA       AA_CODESHARE          AA
# 4       2019-01-01                 AA       AA_CODESHARE          AA
# ...            ...                ...                ...         ...
# 119995  2019-12-01                 WN                 WN          WN
# 119996  2019-12-01                 WN                 WN          WN
# 119997  2019-12-01                 WN                 WN          WN
# 119998  2019-12-01                 WN                 WN          WN
# 119999  2019-12-01                 WN                 WN          WN
#
#         mkt_carrier_fl_num op_unique_carrier tail_num  op_carrier_fl_num  \
# ...

# %%
flights_weather2.to_csv('flights_2019_weather_full.csv',index=False)

# %%
flights['origin'].nunique()
# Out:
# 369

# %%
df = pd.read_csv('flights_2019_weather_full.csv')

# %%
df
# Out:
#            fl_date mkt_unique_carrier branded_code_share mkt_carrier  \
# 0       2019-01-01                 AA       AA_CODESHARE          AA
# 1       2019-01-01                 AA       AA_CODESHARE          AA
# 2       2019-01-01                 AA       AA_CODESHARE          AA
# 3       2019-01-01                 AA       AA_CODESHARE          AA
# 4       2019-01-01                 AA       AA_CODESHARE          AA
# ...            ...                ...                ...         ...
# 119995  2019-12-01                 WN                 WN          WN
# 119996  2019-12-01                 WN                 WN          WN
# 119997  2019-12-01                 WN                 WN          WN
# 119998  2019-12-01                 WN                 WN          WN
# 119999  2019-12-01                 WN                 WN          WN
#
#         mkt_carrier_fl_num op_unique_carrier tail_num  op_carrier_fl_num  \
# ...

# %%
flights['dest'].nunique()
# Out:
# 369

# %%
flights['dep_hour_num']= flights['crs_dep_time']//100
flights['dep_hour_str'] = flights['dep_hour_num'].astype(str)
flights['arr_hour_num']= flights['crs_arr_time']//100
flights['arr_hour_str'] = flights['arr_hour_num'].astype(str)

# %%
dep_condition = []
for x in range(len(flights)):
    url = 'http://api.weatherapi.com/v1/history.json?key='+weather_api+'&q='+flights['origin'][x]+'&dt='+flights['fl_date'][x]+'&hour='+flights['dep_hour_str'][x]
    r = re.get(url)
    res = r.json()  
    dep_condition.append(res['forecast']['forecastday'][0]['hour'][0]['condition']['text'])
flights['dep_condition'] = dep_condition
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~\anaconda3\envs\datasci\lib\site-packages\requests\models.py:972, in Response.json(self, **kwargs)
#     971 try:
# --> 972     return complexjson.loads(self.text, **kwargs)
#     973 except JSONDecodeError as e:
#     974     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     975     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~\anaconda3\envs\datasci\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# ...

# %%
flights['dep_condition'] = dep_condition
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [18], in <cell line: 1>()
# ----> 1 flights['dep_condition'] = dep_condition
#
# File ~\anaconda3\envs\datasci\lib\site-packages\pandas\core\frame.py:3655, in DataFrame.__setitem__(self, key, value)
#    3652     self._setitem_array([key], value)
#    3653 else:
#    3654     # set column
# -> 3655     self._set_item(key, value)
#
# File ~\anaconda3\envs\datasci\lib\site-packages\pandas\core\frame.py:3832, in DataFrame._set_item(self, key, value)
#    3822 def _set_item(self, key, value) -> None:
#    3823     """
#    3824     Add series to DataFrame in specified column.
#    3825
#    (...)
#    3830     ensure homogeneity.
#    3831     """
# -> 3832     value = self._sanitize_column(value)
#    3834     if (
#    3835         key in self.columns
#    3836         and value.ndim == 1
# ...

# %%
len(dep_condition)
# Out:
# 11864

# %%
arr_condition = []
for x in range(len(flights)):
    url = 'http://api.weatherapi.com/v1/history.json?key='+weather_api+'&q='+flights['dest'][x]+'&dt='+flights['arr_date'][x]+'&hour='+flights['arr_hour_str'][x]
    r = re.get(url)
    res = r.json()  
    arr_condition.append(res['forecast']['forecastday'][0]['hour'][0]['condition']['text'])
flights['arr_condition'] = arr_condition
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [23], in <cell line: 2>()
#       2 for x in range(len(flights)):
#       3     url = 'http://api.weatherapi.com/v1/history.json?key='+weather_api+'&q='+flights['dest'][x]+'&dt='+flights['arr_date'][x]+'&hour='+flights['arr_hour_str'][x]
# ----> 4     r = re.get(url)
#       5     res = r.json()
#       6     arr_condition.append(res['forecast']['forecastday'][0]['hour'][0]['condition']['text'])
#
# File ~\anaconda3\envs\datasci\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# ...

# %%
flights.head()
# Out:
#       fl_date mkt_unique_carrier branded_code_share mkt_carrier  \
# 0  2019-01-01                 AA       AA_CODESHARE          AA
# 1  2019-01-01                 AA       AA_CODESHARE          AA
# 2  2019-01-01                 AA       AA_CODESHARE          AA
# 3  2019-01-01                 AA       AA_CODESHARE          AA
# 4  2019-01-01                 AA       AA_CODESHARE          AA
#
#    mkt_carrier_fl_num op_unique_carrier tail_num  op_carrier_fl_num  \
# 0                3044                OO   N761ND               3044
# 1                5606                OH   N575NN               5606
# 2                5607                OH   N254PS               5607
# 3                5607                OH   N254PS               5607
# 4                5608                OH   N710PS               5608
#
#    origin_airport_id origin  ... late_aircraft_delay  first_dep_time  \
# 0              13930    ORD  ...                 0.0             NaN
# ...

# %%
len(arr_condition)
# Out:
# 654

# %%
len(arr_condition)
# Out:
# 2021
